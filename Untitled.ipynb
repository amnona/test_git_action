# %%
import calour as ca

# %%
# %matplotlib notebook

# %%
dat=ca.read_amplicon('/Users/amnon/Projects/chronic-fatigue-syndrome/all.biom',
                     '/Users/amnon/Projects/chronic-fatigue-syndrome/map.joined.txt',
                     normalize=10000,min_reads=1000)
# Out:
# 2020-11-22 19:52:43 WARNING These have metadata but do not have data - dropped (1): {'ERR1331814'}
# 2020-11-22 19:52:43 WARNING Do you forget to normalize your data? It is required before running this function

# %%
datc=dat.cluster_features(10)

# %%
datc.sample_metadata.Subject.unique()
# Out:
# array(['Patient', 'Control'], dtype=object)

# %%
dd=datc.diff_abundance('Subject','Patient')

# %%
dd.plot(gui='jupyter')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Label(value='0 features are selected')
# ...
# HTML(value='no annotation found', layout=Layout(height='100px', overflow_y='auto'))

# %%
dd.plot_diff_abundance_enrichment()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fe880b867b8>,
#  Experiment with 60 samples, 381 features)
